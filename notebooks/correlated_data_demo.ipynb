# %% [markdown]
# # Correlated Data Demo
#
# This notebook is a thin wrapper around the Python modules in `src/`. It generates
# correlated 2D samples and visualizes them using the reusable functions in
# `src.data.loaders`.

# %%
import sys, os
repo_root = os.path.abspath("..")  # go up from notebooks/ to project root
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)
